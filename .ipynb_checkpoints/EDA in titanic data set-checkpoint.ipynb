# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Why do EDA
#
# - Model building
# - Analysis and reporting
# - Validate assumptions
# - Handling missing values
# - feature engineering
# - detecting outliers
# - # Remember it is an iterative process

# %% [markdown]
# ### Column Types
#
# - **Numerical** - Age,Fare,PassengerId
# - **Categorical** - Survived, Pclass, Sex, SibSp, Parch,Embarked
# - **Mixed** - Name, Ticket, Cabin

# %% [markdown]
# ### Univariate Analysis
#
# Univariate analysis focuses on analyzing each feature in the dataset independently.
#
# - **Distribution analysis**: The distribution of each feature is examined to identify its shape, central tendency, and dispersion.
#
# - **Identifying potential issues**: Univariate analysis helps in identifying potential problems with the data such as outliers, skewness, and missing values

# %% [markdown]
# #### The shape of a data distribution refers to its overall pattern or form as it is represented on a graph. Some common shapes of data distributions include:
#
# - **Normal Distribution**: A symmetrical and bell-shaped distribution where the mean, median, and mode are equal and the majority of the data falls in the middle of the distribution with gradually decreasing frequencies towards the tails.
#
# - **Skewed Distribution**: A distribution that is not symmetrical, with one tail being longer than the other. It can be either positively skewed (right-skewed) or negatively skewed (left-skewed).
#
# - **Bimodal Distribution**: A distribution with two peaks or modes.
#
# - **Uniform Distribution**: A distribution where all values have an equal chance of occurring.
#
# The shape of the data distribution is important in identifying the presence of outliers, skewness, and the type of statistical tests and models that can be used for further analysis.

# %% [markdown]
# ### Steps of doing Univariate Analysis on Numerical columns
#
# - **Descriptive Statistics**: Compute basic summary statistics for the column, such as mean, median, mode, standard deviation, range, and quartiles. These statistics give a general understanding of the distribution of the data and can help identify skewness or outliers.
#
# - **Visualizations**: Create visualizations to explore the distribution of the data. Some common visualizations for numerical data include histograms, box plots, and density plots. These visualizations provide a visual representation of the distribution of the data and can help identify skewness an outliers.
#
# - **Identifying Outliers**: Identify and examine any outliers in the data. Outliers can be identified using visualizations. It is important to determine whether the outliers are due to measurement errors, data entry errors, or legitimate differences in the data, and to decide whether to include or exclude them from the analysis.
#
# - **Skewness**: Check for skewness in the data and consider transforming the data or using robust statistical methods that are less sensitive to skewness, if necessary.
#
# - **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %%
df.to_excel("titanic.xlsx")

# %%
df1 = df.copy()

# %%
temp = df1["Name"].str.split(",").str.get(0)
df1.insert(4,"surname",temp)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name    surname     Sex  \
# 0                              Braund, Mr. Owen Harris     Braund    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    Cumings  female
# 2                               Heikkinen, Miss. Laina  Heikkinen  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   Futrelle  female
# 4                             Allen, Mr. William Henry      Allen    male
# ..                                                 ...        ...     ...
# ...

# %% [markdown]
# ### Age
#
# **conclusions**
#
# - Age is normally(almost) distributed
# - 20% of the values are missing
# - There are some outliers

# %%
df1["Age"].value_counts().sum()
# Out:
# 714

# %%
df1["Age"].isnull().sum()
# Out:
# 177

# %%
df1["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df1["Age"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1["Age"].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df1["Age"].skew() # it is 0.39 so near by normal distribution it is not perfect normal distrubution
# Out:
# 0.38910778230082704

# %%
df1["Age"].plot(kind="box")
# Out:
# <Axes: >

# %%
df1[df1["Age"] > 65]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#           surname   Sex   Age  SibSp  Parch      Ticket     Fare Cabin  \
# 33        Wheadon  male  66.0      0      0  C.A. 24579  10.5000   NaN
# 96    Goldschmidt  male  71.0      0      0    PC 17754  34.6542    A5
# 116       Connors  male  70.5      0      0      370369   7.7500   NaN
# ...

# %%
df1[df1["Age"] < 65]["Age"].mean()
# Out:
# 29.07207681365576

# %% [markdown]
# ### Fare
#
# **conclusions**
#
# - The data is highly(positively) skewed
# - Fare col actually contains the group fare and not the individual fare(This migth be and issue)
# - We need to create a new col called individual fare

# %%
df1["Fare"].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df1["Fare"].isnull().sum()
# Out:
# 0

# %%
df1["Fare"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1["Fare"].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df1["Fare"].skew()
# Out:
# 4.787316519674893

# %%
df1["Fare"].plot(kind="box")
# Out:
# <Axes: >

# %%
df1[df1["Fare"] > 31 ]["Pclass"].value_counts()
# Out:
# Pclass
# 1    159
# 3     41
# 2     22
# Name: count, dtype: int64

# %%
df1[df1["Fare"] > 100 ]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
# 215          216         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 297          298         0       1
# 299          300         1       1
# 305          306         1       1
# 306          307         1       1
# 307          308         1       1
# 311          312         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 332          333         0       1
# 334          335         1       1
# 337          338         1       1
# 341          342         1       1
# 373          374         0       1
# 377          378         0       1
# 380          381         1       1
# ...

# %% [markdown]
# ### Steps of doing Univariate Analysis on Categorical columns
#
# **Descriptive Statistics**: Compute the frequency distribution of the categories in the column. This will give a general understanding of the distribution of the categories and their relative frequencies.
#
# **Visualizations**: Create visualizations to explore the distribution of the categories. Some common visualizations for categorical data include count plots and pie charts. These visualizations provide a visual representation of the distribution of the categories and can help identify any patterns or anomalies in the data.
#
# **Missing Values**: Check for missing values in the data and decide how to handle them. Missing values can be imputed or excluded from the analysis, depending on the research question and the data set.
#
# **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %%
df1["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
(549/891)*100
# Out:
# 61.61616161616161

# %%
df1["Survived"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Survived
#
# **conclusions**
#
# - Parch and SibSp cols can be merged to form  a new col call family_size
# - Create a new col called is_alone

# %%
df1["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df1["Pclass"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1["Pclass"].value_counts().plot(kind="pie",autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df1["Pclass"].isnull().sum()
# Out:
# 0

# %%
df1["Sex"].value_counts().plot(kind="pie",autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df1["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# ### Steps of doing Bivariate Analysis
#
# - Select 2 cols
# - Understand type of relationship
#     1. **Numerical - Numerical**<br>
#         a. You can plot graphs like scatterplot(regression plots), 2D histplot, 2D KDEplots<br>
#         b. Check correlation coefficent to check linear relationship
#     2. **Numerical - Categorical** - create visualizations that compare the distribution of the numerical data across different categories of the categorical data.<br>
#         a. You can plot graphs like barplot, boxplot, kdeplot violinplot even scatterplots<br>
#     3. **Categorical - Categorical**<br>
#         a. You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column.<br>
#         b. You can plots like heatmap, stacked barplots, treemaps
#
# - Write your conclusions

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name    surname     Sex  \
# 0                              Braund, Mr. Owen Harris     Braund    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    Cumings  female
# 2                               Heikkinen, Miss. Laina  Heikkinen  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   Futrelle  female
# 4                             Allen, Mr. William Henry      Allen    male
# ..                                                 ...        ...     ...
# ...

# %%
df1["Title"].fillna(df1["Name"].str.split(",").str.get(1).str.strip().str.split(".").str.get(0),inplace=True)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass Title  \
# 0              1         0       3    Mr
# 1              2         1       1   Mrs
# 2              3         1       3  Miss
# 3              4         1       1   Mrs
# 4              5         0       3    Mr
# ..           ...       ...     ...   ...
# 886          887         0       2   Rev
# 887          888         1       1  Miss
# 888          889         0       3  Miss
# 889          890         1       1    Mr
# 890          891         0       3    Mr
#
#                                                   Name    surname     Sex  \
# 0                              Braund, Mr. Owen Harris     Braund    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    Cumings  female
# 2                               Heikkinen, Miss. Laina  Heikkinen  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   Futrelle  female
# 4                             Allen, Mr. William Henry      Allen    male
# ...

# %%
df1["Title"].value_counts()
# Out:
# Title
# Mr              517
# Miss            182
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Mlle              2
# Major             2
# Col               2
# the Countess      1
# Capt              1
# Ms                1
# Sir               1
# Lady              1
# Mme               1
# Don               1
# Jonkheer          1
# Name: count, dtype: int64

# %%
df1["Title"] = df1["Title"].replace().apply(lambda x : 'other' if x in ["Dr","Rev","Major","Col","the Countess","Capt","Sir","Don","Jonkheer","Mlle","Mme","Ms","Lady"] else x).value_counts()
# Out:
# C:\Users\jayde\AppData\Local\Temp\ipykernel_9176\3708712071.py:1: FutureWarning: Series.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df1["Title"] = df1["Title"].replace().apply(lambda x : 'other' if x in ["Dr","Rev","Major","Col","the Countess","Capt","Sir","Don","Jonkheer","Mlle","Mme","Ms","Lady"] else x).value_counts()

# %%
df1["Title"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass Title  \
# 0              1         0       3    Mr
# 1              2         1       1   Mrs
# 2              3         1       3  Miss
# 3              4         1       1   Mrs
# 4              5         0       3    Mr
# ..           ...       ...     ...   ...
# 886          887         0       2   Rev
# 887          888         1       1  Miss
# 888          889         0       3  Miss
# 889          890         1       1    Mr
# 890          891         0       3    Mr
#
#                                                   Name    surname     Sex  \
# 0                              Braund, Mr. Owen Harris     Braund    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    Cumings  female
# 2                               Heikkinen, Miss. Laina  Heikkinen  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   Futrelle  female
# 4                             Allen, Mr. William Henry      Allen    male
# ...

# %%
temp_df = pd.read_csv("test.csv")
temp_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
temp_df.insert(3,"Surname",temp_df["Name"].str.split(",").str.get(0))

# %%
temp_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#            Surname     Sex   Age  SibSp  Parch              Ticket      Fare  \
# ...

# %%
temp_df.insert(2,"Title",temp_df["Name"].str.split(",").str.get(1).str.strip().str.split(".").str.get(0))

# %%
temp_df
# Out:
#      PassengerId  Pclass   Title  \
# 0            892       3      Mr
# 1            893       3     Mrs
# 2            894       2      Mr
# 3            895       3      Mr
# 4            896       3     Mrs
# ..           ...     ...     ...
# 413         1305       3      Mr
# 414         1306       1    Dona
# 415         1307       3      Mr
# 416         1308       3      Mr
# 417         1309       3  Master
#
#                                              Name        Surname     Sex  \
# 0                                Kelly, Mr. James          Kelly    male
# 1                Wilkes, Mrs. James (Ellen Needs)         Wilkes  female
# 2                       Myles, Mr. Thomas Francis          Myles    male
# 3                                Wirz, Mr. Albert           Wirz    male
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)       Hirvonen  female
# ..                                            ...            ...     ...
# ...

# %%
df1 = pd.concat([df1,temp_df], ignore_index=True)

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass Title  \
# 0            1       0.0       3    Mr
# 1            2       1.0       1   Mrs
# 2            3       1.0       3  Miss
# 3            4       1.0       1   Mrs
# 4            5       0.0       3    Mr
#
#                                                 Name    surname     Sex   Age  \
# 0                            Braund, Mr. Owen Harris     Braund    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    Cumings  female  38.0
# 2                             Heikkinen, Miss. Laina  Heikkinen  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   Futrelle  female  35.0
# 4                           Allen, Mr. William Henry      Allen    male  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked Surname
# 0      1      0         A/5 21171   7.2500   NaN        S     NaN
# 1      1      0          PC 17599  71.2833   C85        C     NaN
# ...

# %%
df1["Title"].value_counts()
# Out:
# Title
# Mr              757
# Miss            260
# Mrs             197
# Master           61
# Rev               8
# Dr                8
# Col               4
# Mlle              2
# Major             2
# Ms                2
# Lady              1
# Sir               1
# Mme               1
# Don               1
# Capt              1
# the Countess      1
# Jonkheer          1
# Dona              1
# Name: count, dtype: int64

# %%
df1["Title"] = df1["Title"].replace("Rev","other")
df1["Title"] = df1["Title"].replace("Dr","other")
df1["Title"] = df1["Title"].replace("Col","other")
df1["Title"] = df1["Title"].replace("Mlle","other")
df1["Title"] = df1["Title"].replace("Major","other")
df1["Title"] = df1["Title"].replace("Ms","other")
df1["Title"] = df1["Title"].replace("Lady","other")
df1["Title"] = df1["Title"].replace("Sir","other")
df1["Title"] = df1["Title"].replace("Mme","other")
df1["Title"] = df1["Title"].replace("Don","other")
df1["Title"] = df1["Title"].replace("Capt","other")
df1["Title"] = df1["Title"].replace("the Countess","other")
df1["Title"] = df1["Title"].replace("Jonkheer","other")
df1["Title"] = df1["Title"].replace("Dona","other")

# %%
df1["Title"].value_counts()
# Out:
# Title
# Mr        757
# Miss      260
# Mrs       197
# Master     61
# other      34
# Name: count, dtype: int64

# %%
df1
# Out:
#       PassengerId  Survived  Pclass   Title  \
# 0               1       0.0       3      Mr
# 1               2       1.0       1     Mrs
# 2               3       1.0       3    Miss
# 3               4       1.0       1     Mrs
# 4               5       0.0       3      Mr
# ...           ...       ...     ...     ...
# 1304         1305       NaN       3      Mr
# 1305         1306       NaN       1   other
# 1306         1307       NaN       3      Mr
# 1307         1308       NaN       3      Mr
# 1308         1309       NaN       3  Master
#
#                                                    Name    surname     Sex  \
# 0                               Braund, Mr. Owen Harris     Braund    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...    Cumings  female
# 2                                Heikkinen, Miss. Laina  Heikkinen  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)   Futrelle  female
# ...

# %%
pd.crosstab(df['Survived'],df['Pclass'],normalize='columns')*100
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %%
sns.heatmap(pd.crosstab(df['Survived'],df['Pclass'],normalize='columns')*100)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# ### Categorical - Categorical
# ## Pclass and Survived
# `Conclusion`
# - For Class 1 Survived chance is 62%
# - for class 3 Survived chance is 24%
# - So for high class and you can say that rich people have high change for Survived

# %%
pd.crosstab(df1["Survived"],[df1["Pclass"],df1["Sex"]],normalize='columns')*100
# Out:
# Pclass            1                     2                 3
# Sex          female       male     female       male female       male
# Survived
# 0.0        3.191489  63.114754   7.894737  84.259259   50.0  86.455331
# 1.0       96.808511  36.885246  92.105263  15.740741   50.0  13.544669

# %%
pd.crosstab(df1["Survived"],df1["Sex"],normalize='columns')*100
# Out:
# Sex          female       male
# Survived
# 0.0       25.796178  81.109185
# 1.0       74.203822  18.890815

# %% [markdown]
# ### Categorical - Categorical
# ## Pclass and Survived and sex
# `Conclusion`
# - For Class 1 female Survived chance is 3.19% for male 63%
# - for class 3 Survived chance is 50% and for male it is 86.45%
# - overall for female survived rate is high compare to male

# %%
pd.crosstab(df['Sex'],df['Embarked'],normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Sex
# female    43.452381  46.753247  31.521739
# male      56.547619  53.246753  68.478261

# %%
pd.crosstab(df['Pclass'],df['Embarked'],normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %%
# survived and age

df[df['Survived'] == 1]['Age'].plot(kind='kde',label='Survived')
df[df['Survived'] == 0]['Age'].plot(kind='kde',label='Not Survived')

plt.legend()
plt.show()

# %%
df1[df1['Pclass'] == 1]['Age'].mean()
# Out:
# 39.15992957746479

# %%
df1[df1["Age"] < 5]["Age"].mean()
# Out:
# 2.0229411764705882

# %%
df1.drop(columns="Surname",inplace=True)

# %%
df1
# Out:
#       PassengerId  Survived  Pclass   Title  \
# 0               1       0.0       3      Mr
# 1               2       1.0       1     Mrs
# 2               3       1.0       3    Miss
# 3               4       1.0       1     Mrs
# 4               5       0.0       3      Mr
# ...           ...       ...     ...     ...
# 1304         1305       NaN       3      Mr
# 1305         1306       NaN       1   other
# 1306         1307       NaN       3      Mr
# 1307         1308       NaN       3      Mr
# 1308         1309       NaN       3  Master
#
#                                                    Name    surname     Sex  \
# 0                               Braund, Mr. Owen Harris     Braund    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...    Cumings  female
# 2                                Heikkinen, Miss. Laina  Heikkinen  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)   Futrelle  female
# ...

# %%
# Feature Engineering on fare col

# %%
df1["SibSp"].value_counts()
# Out:
# SibSp
# 0    891
# 1    319
# 2     42
# 4     22
# 3     20
# 8      9
# 5      6
# Name: count, dtype: int64

# %%
df1.insert(12,"Single_fare",df1["Fare"]/(df1["SibSp"]+df1["Parch"]+1))

# %%
df1
# Out:
#       PassengerId  Survived  Pclass   Title  \
# 0               1       0.0       3      Mr
# 1               2       1.0       1     Mrs
# 2               3       1.0       3    Miss
# 3               4       1.0       1     Mrs
# 4               5       0.0       3      Mr
# ...           ...       ...     ...     ...
# 1304         1305       NaN       3      Mr
# 1305         1306       NaN       1   other
# 1306         1307       NaN       3      Mr
# 1307         1308       NaN       3      Mr
# 1308         1309       NaN       3  Master
#
#                                                    Name    surname     Sex  \
# 0                               Braund, Mr. Owen Harris     Braund    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...    Cumings  female
# 2                                Heikkinen, Miss. Laina  Heikkinen  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)   Futrelle  female
# ...

# %%
df1["Single_fare"].plot(kind="box")
# Out:
# <Axes: >

# %%
df1['family_size'] = df1['SibSp'] + df1['Parch'] + 1

# %%
df1[df1["Single_fare"] > 500]
# Out:
#      PassengerId  Survived  Pclass Title                    Name  surname  \
# 258          259       1.0       1  Miss        Ward, Miss. Anna     Ward
# 737          738       1.0       1    Mr  Lesurer, Mr. Gustave J  Lesurer
#
#         Sex   Age  SibSp  Parch    Ticket      Fare  Single_fare Cabin  \
# 258  female  35.0      0      0  PC 17755  512.3292     512.3292   NaN
# 737    male  35.0      0      0  PC 17755  512.3292     512.3292  B101
#
#     Embarked  family_size
# 258        C            1
# 737        C            1

# %%
df1[['Single_fare','Fare']].describe()
# Out:
#        Single_fare         Fare
# count  1308.000000  1308.000000
# mean     20.518215    33.295479
# std      35.774337    51.758668
# min       0.000000     0.000000
# 25%       7.452767     7.895800
# 50%       8.512483    14.454200
# 75%      24.237500    31.275000
# max     512.329200   512.329200

# %%
df1
# Out:
#       PassengerId  Survived  Pclass   Title  \
# 0               1       0.0       3      Mr
# 1               2       1.0       1     Mrs
# 2               3       1.0       3    Miss
# 3               4       1.0       1     Mrs
# 4               5       0.0       3      Mr
# ...           ...       ...     ...     ...
# 1304         1305       NaN       3      Mr
# 1305         1306       NaN       1   other
# 1306         1307       NaN       3      Mr
# 1307         1308       NaN       3      Mr
# 1308         1309       NaN       3  Master
#
#                                                    Name    surname     Sex  \
# 0                               Braund, Mr. Owen Harris     Braund    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...    Cumings  female
# 2                                Heikkinen, Miss. Laina  Heikkinen  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)   Futrelle  female
# ...

# %%
# family_type
# 1 -> alone
# 2-4 -> small
# >5 -> large

def Family_size(num):
    if num == 1:
        return "alone"
    elif num > 1  and num < 5:
        return "small"
    else:
        return "large"

# %%
df1["family_type"] = df1["family_size"].apply(Family_size)

# %%
df1
# Out:
#       PassengerId  Survived  Pclass   Title  \
# 0               1       0.0       3      Mr
# 1               2       1.0       1     Mrs
# 2               3       1.0       3    Miss
# 3               4       1.0       1     Mrs
# 4               5       0.0       3      Mr
# ...           ...       ...     ...     ...
# 1304         1305       NaN       3      Mr
# 1305         1306       NaN       1   other
# 1306         1307       NaN       3      Mr
# 1307         1308       NaN       3      Mr
# 1308         1309       NaN       3  Master
#
#                                                    Name    surname     Sex  \
# 0                               Braund, Mr. Owen Harris     Braund    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...    Cumings  female
# 2                                Heikkinen, Miss. Laina  Heikkinen  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)   Futrelle  female
# ...

# %%
pd.crosstab(df1['Survived'],df1['family_type'],normalize='columns')*100
# Out:
# family_type      alone      large      small
# Survived
# 0.0          69.646182  83.870968  42.123288
# 1.0          30.353818  16.129032  57.876712

# %% [markdown]
# ### Categorical - Categorical
# ## Survived and family_type
# `Conclusion`
# - for alone survival rate is low
# - for large family survival rate is large

# %%
df1['surname'] = df1['Name'].str.split(',').str.get(0)

# %%
df1
# Out:
#       PassengerId  Survived  Pclass   Title  \
# 0               1       0.0       3      Mr
# 1               2       1.0       1     Mrs
# 2               3       1.0       3    Miss
# 3               4       1.0       1     Mrs
# 4               5       0.0       3      Mr
# ...           ...       ...     ...     ...
# 1304         1305       NaN       3      Mr
# 1305         1306       NaN       1   other
# 1306         1307       NaN       3      Mr
# 1307         1308       NaN       3      Mr
# 1308         1309       NaN       3  Master
#
#                                                    Name        surname  \
# 0                               Braund, Mr. Owen Harris         Braund
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...        Cumings
# 2                                Heikkinen, Miss. Laina      Heikkinen
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)       Futrelle
# 4                              Allen, Mr. William Henry          Allen
# ...

# %%
df1["Cabin"].isnull().sum()/len(df1)
# Out:
# 0.774637127578304

# %%
df1['Cabin'].fillna('M',inplace=True)
# Out:
# C:\Users\jayde\AppData\Local\Temp\ipykernel_9176\1549919824.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['Cabin'].fillna('M',inplace=True)

# %%
df1.insert(15,"deck" , df1["Cabin"].str[0])

# %%
df1
# Out:
#       PassengerId  Survived  Pclass   Title  \
# 0               1       0.0       3      Mr
# 1               2       1.0       1     Mrs
# 2               3       1.0       3    Miss
# 3               4       1.0       1     Mrs
# 4               5       0.0       3      Mr
# ...           ...       ...     ...     ...
# 1304         1305       NaN       3      Mr
# 1305         1306       NaN       1   other
# 1306         1307       NaN       3      Mr
# 1307         1308       NaN       3      Mr
# 1308         1309       NaN       3  Master
#
#                                                    Name        surname  \
# 0                               Braund, Mr. Owen Harris         Braund
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...        Cumings
# 2                                Heikkinen, Miss. Laina      Heikkinen
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)       Futrelle
# 4                              Allen, Mr. William Henry          Allen
# ...

# %%
pd.crosstab(df1['deck'],df1['Pclass'])
# Out:
# Pclass   1    2    3
# deck
# A       22    0    0
# B       65    0    0
# C       94    0    0
# D       40    6    0
# E       34    4    3
# F        0   13    8
# G        0    0    5
# M       67  254  693
# T        1    0    0

# %%
pd.crosstab(df1['deck'],df1['Survived'],normalize='index').plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='deck'>

# %%
sns.heatmap(df1.corr())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[210], line 1
# ----> 1 sns.heatmap(df1.corr())
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
sns.pairplot(df1)

# %%
df1[~df1["Ticket"].str.isdigit()]["deck"].value_counts()
# Out:
# deck
# M    268
# B     25
# C     23
# E     12
# D     11
# A      7
# G      3
# F      3
# Name: count, dtype: int64
